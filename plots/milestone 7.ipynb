# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


# Define the path to the data folder
data_folder = 'C:/Users/moses_y/OneDrive/Desktop/plots/data/'

# Load the GTFS files into DataFrames
agency = pd.read_csv(data_folder + 'agency.txt')
calendar = pd.read_csv(data_folder + 'calendar.txt')
calendar_dates = pd.read_csv(data_folder + 'calendar_dates.txt')
feed_info = pd.read_csv(data_folder + 'feed_info.txt')
frequencies = pd.read_csv(data_folder + 'frequencies.txt')
routes = pd.read_csv(data_folder + 'routes.txt')
shapes = pd.read_csv(data_folder + 'shapes.txt')
stop_times = pd.read_csv(data_folder + 'stop_times.txt')
stops = pd.read_csv(data_folder + 'stops.txt')
trips = pd.read_csv(data_folder + 'trips.txt')

# Explore the data and perform necessary data manipulations
# For example, you can print the head of a DataFrame to check the data
routes.head()
# Out:
#       route_id agency_id route_short_name route_long_name  \
# 0  10100011A11       UON              11A       Highridge
# 1  10300011F11       UON              11F           Ruaka
# 2  10300106011       UON              106          Banana
# 3  10400010711       UON              107        Ndenderu
# 4  10200010811       UON              108          Gachie
#
#                       route_desc  route_type  route_url  route_color  \
# 0        Odeon-AgaKhan-HighRidge           3        NaN          NaN
# 1                 Odeon-UN-Ruaka           3        NaN          NaN
# 2          Odeon-UN-Ruaka-Banana           3        NaN          NaN
# 3        Odeon-UN-Ruaka-Ndenderu           3        NaN          NaN
# 4  UN-NewMuthaiga-Gachie-Gichagi           3        NaN          NaN
#
#    route_text_color
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN

# %%
trips.head()
# Out:
#       route_id service_id   trip_id trip_headsign  direction_id  block_id  \
# 0  10100011A11      DAILY  1011A111    From Odeon             1       NaN
# 1  10100011A11      DAILY  1011A110      To Odeon             0       NaN
# 2  10300011F11      DAILY  1011F111    From Odeon             1       NaN
# 3  10300011F11      DAILY  1011F110      To Odeon             0       NaN
# 4  10300106011      DAILY  10106111     From Koja             1       NaN
#
#   shape_id
# 0  1011A11
# 1  1011A11
# 2  1011F11
# 3  1011F11
# 4  1010611

# %%
stops.head()
# Out:
#    stop_id  stop_code    stop_name stop_desc  stop_lat   stop_lon  zone_id  \
# 0  0005AMB        NaN  Ambassadeur         D -1.285963  36.826048      NaN
# 1  0006BSS        NaN  Bus Station         D -1.287191  36.828881      NaN
# 2  0007COM        NaN   Commercial         D -1.284282  36.826188      NaN
# 3  0512BST        NaN  Bus Station         D -1.287281  36.828863      NaN
# 4  0512BSN        NaN  Bus Station         D -1.287635  36.829215      NaN
#
#    stop_url  location_type parent_station
# 0       NaN            1.0            NaN
# 1       NaN            1.0            NaN
# 2       NaN            1.0            NaN
# 3       NaN            NaN        0006BSS
# 4       NaN            NaN        0006BSS

# %%
stop_times.head()
# Out:
#     trip_id arrival_time departure_time  stop_id  stop_sequence  \
# 0  40006111      6:00:00        6:00:00  0412CAR              1
# 1  40006111      6:02:00        6:02:00  0411RIK              2
# 2  40006111      6:04:00        6:04:00  0411JNV              3
# 3  40006111      6:06:00        6:06:00  0401BFR              4
# 4  40006111      6:08:00        6:08:00  0411BFR              5
#
#    stop_headsign  pickup_type  shape_dist_traveled
# 0            NaN          NaN                  NaN
# 1            NaN          NaN                  NaN
# 2            NaN          NaN                  NaN
# 3            NaN          NaN                  NaN
# 4            NaN          NaN                  NaN

# %%
shapes.head()
# Out:
#   shape_id  shape_pt_lat  shape_pt_lon  shape_pt_sequence  shape_dist_traveled
# 0  4000611     -1.294705     36.853271               1001                  NaN
# 1  4000611     -1.294484     36.852337               1002                  NaN
# 2  4000611     -1.294484     36.852337               1003                  NaN
# 3  4000611     -1.294378     36.851830               1004                  NaN
# 4  4000611     -1.294322     36.851715               1005                  NaN

# %%
calendar.head()
# Out:
#   service_id  monday  tuesday  wednesday  thursday  friday  saturday  sunday  \
# 0      DAILY       1        1          1         1       1         1       1
# 1      SPCDY       1        1          1         1       1         1       1
#
#    start_date  end_date
# 0    20140101  20151231
# 1    20140101  20151231

# %%
trips.head()
# Out:
#       route_id service_id   trip_id trip_headsign  direction_id  block_id  \
# 0  10100011A11      DAILY  1011A111    From Odeon             1       NaN
# 1  10100011A11      DAILY  1011A110      To Odeon             0       NaN
# 2  10300011F11      DAILY  1011F111    From Odeon             1       NaN
# 3  10300011F11      DAILY  1011F110      To Odeon             0       NaN
# 4  10300106011      DAILY  10106111     From Koja             1       NaN
#
#   shape_id
# 0  1011A11
# 1  1011A11
# 2  1011F11
# 3  1011F11
# 4  1010611

# %%
frequencies.head()
# Out:
#     trip_id start_time  end_time  headway_secs
# 0  1011A111    6:00:00   9:00:00           300
# 1  1011A111    9:01:00  15:00:00           900
# 2  1011A111   15:01:00  21:00:00           300
# 3  1011A110    6:00:00   9:00:00           300
# 4  1011A110    9:01:00  15:00:00           900

# %%
agency.head()
# Out:
#   agency_id                   agency_name              agency_url  \
# 0       UON  University Of Nairobi C4DLab  http://www.uonbi.ac.ke
#
#   agency_timezone agency_lang  agency_phone  agency_fare_url
# 0  Africa/Nairobi          en           NaN              NaN

# %%
calendar_dates.head()
# Out:
#   service_id      date  exception_type
# 0      DAILY  20140526               2
# 1      SPCDY  20140310               2

# %%
feed_info.head()
# Out:
#   feed_publisher_name              feed_publisher_url feed_lang  \
# 0     Digital Matatus  http://www.digitalmatatus.com/        en
#
#    feed_start_date  feed_end_date  feed_version
# 0         20120302       20150524           NaN

# %%
# Plot Pie Chart
weekday_columns = ['monday', 'tuesday', 'wednesday', 'thursday', 'friday', 'saturday', 'sunday']
weekday_counts = calendar[weekday_columns].sum()

plt.pie(weekday_counts, labels=weekday_columns, autopct='%1.1f%%')
plt.title('Distribution of Weekdays')
plt.axis('equal')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Define the path to the data folder
data_folder = 'C:/Users/moses_y/OneDrive/Desktop/plots/data/'

# Load the GTFS files into DataFrames
agency = pd.read_csv(data_folder + 'agency.txt')
calendar = pd.read_csv(data_folder + 'calendar.txt')
calendar_dates = pd.read_csv(data_folder + 'calendar_dates.txt')
feed_info = pd.read_csv(data_folder + 'feed_info.txt')
frequencies = pd.read_csv(data_folder + 'frequencies.txt')
routes = pd.read_csv(data_folder + 'routes.txt')
shapes = pd.read_csv(data_folder + 'shapes.txt')
stops = pd.read_csv(data_folder + 'stops.txt')
trips = pd.read_csv(data_folder + 'trips.txt')

# Select the necessary columns from the stops and trips DataFrames
stops_data = stops[['stop_id', 'stop_lat', 'stop_lon']]
trips_data = trips[['route_id', 'trip_id']]

# Combine the selected DataFrames into a single DataFrame
all_data = pd.concat([stops_data, trips_data], axis=1)

# Exclude non-numeric columns from the combined DataFrame
numeric_columns = all_data.select_dtypes(include=[float, int]).columns
numeric_data = all_data[numeric_columns]

# Fill null values with the mean of respective columns
numeric_data_filled = numeric_data.fillna(numeric_data.mean())

# Calculate the correlation matrix
correlation_matrix = numeric_data_filled.corr()

# Plot the correlation matrix as a heatmap with adjusted color scheme
plt.figure(figsize=(10, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='copper')
plt.title('Correlation Matrix of GTFS Data')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Define the path to the data folder
data_folder = 'C:/Users/moses_y/OneDrive/Desktop/plots/data/'

# Load the GTFS files into DataFrames
agency = pd.read_csv(data_folder + 'agency.txt')
calendar = pd.read_csv(data_folder + 'calendar.txt')
calendar_dates = pd.read_csv(data_folder + 'calendar_dates.txt')
feed_info = pd.read_csv(data_folder + 'feed_info.txt')
frequencies = pd.read_csv(data_folder + 'frequencies.txt')
routes = pd.read_csv(data_folder + 'routes.txt')
shapes = pd.read_csv(data_folder + 'shapes.txt')
stops = pd.read_csv(data_folder + 'stops.txt')
trips = pd.read_csv(data_folder + 'trips.txt')

# Merge 'trips' and 'frequencies' DataFrames on 'trip_id'
trips = trips.merge(frequencies, on='trip_id')

# Convert 'start_time' and 'end_time' columns to datetime type
trips['start_time'] = pd.to_datetime(trips['start_time'], format='%H:%M:%S')
trips['end_time'] = pd.to_datetime(trips['end_time'], format='%H:%M:%S')

# Check if 'trip_duration' column exists in the DataFrame
if 'trip_duration' not in trips.columns:
    # Calculate trip duration
    trips['trip_duration'] = trips['end_time'] - trips['start_time']

# Convert trip_duration to numeric format
trips['trip_duration'] = trips['trip_duration'].dt.total_seconds() / 60

# Filter out invalid or missing data
trips = trips.dropna(subset=['route_id', 'trip_duration'])

# Check if any valid trip durations exist
if trips['trip_duration'].empty:
    print("No valid trip durations found.")
else:
    # Calculate average trip duration
    average_trip_duration = trips['trip_duration'].mean()
    print("Average Trip Duration:", average_trip_duration)

    # Plot the bar chart for average trip duration by route ID
    plt.figure(figsize=(16, 8))  # Adjust the figure size
    ax = sns.barplot(x='route_id', y='trip_duration', data=trips)
    plt.xlabel('Route ID')
    plt.ylabel('Trip Duration (minutes)')
    plt.title(f'Average Trip Duration by Route ID\n(Average: {average_trip_duration:.2f} minutes)')  # Include average in the plot title
    plt.xticks(rotation=60)  # Rotate the x-axis labels by 30 degrees
    plt.tight_layout()  # Adjust the spacing of the plot

    # Adjust the x-axis labels to start at 0
    ax.set_xlim(left=0)
    plt.ylim(0, None)

    plt.show()
# Out:
# Average Trip Duration: 299.63315266486

# %%
# Plot Histogram
sns.histplot(stop_times['stop_sequence'], bins=20)
plt.xlabel('Stop Sequence')
plt.ylabel('Frequency')
plt.title('Distribution of Stop Sequences')
plt.show()

# %%
# Plot Categorical Plot (Count)
sns.countplot(x='route_type', data=routes)
plt.xlabel('Route Type')
plt.ylabel('Count')
plt.title('Distribution of Route Types')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the stops DataFrame
stops = pd.read_csv(data_folder + 'stops.txt')

# Plot the count of stops by location type
plt.figure(figsize=(10, 6))
sns.countplot(x='location_type', data=stops)
plt.xlabel('Location Type')
plt.ylabel('Count')
plt.title('Count of Stops by Location Type')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Define the path to the data folder
data_folder = 'C:/Users/moses_y/OneDrive/Desktop/plots/data/'

# Load the GTFS files into DataFrames
agency = pd.read_csv(data_folder + 'agency.txt')
calendar = pd.read_csv(data_folder + 'calendar.txt')
calendar_dates = pd.read_csv(data_folder + 'calendar_dates.txt')
feed_info = pd.read_csv(data_folder + 'feed_info.txt')
frequencies = pd.read_csv(data_folder + 'frequencies.txt')
routes = pd.read_csv(data_folder + 'routes.txt')
shapes = pd.read_csv(data_folder + 'shapes.txt')
stop_times = pd.read_csv(data_folder + 'stop_times.txt')
stops = pd.read_csv(data_folder + 'stops.txt')
trips = pd.read_csv(data_folder + 'trips.txt')

# Extract the 'route_long_name' and 'route_desc' columns from 'routes' DataFrame
route_names = routes['route_long_name']
route_descs = routes['route_desc']

# Plot route names
plt.figure(figsize=(18, 6))
route_names.value_counts().plot(kind='bar')
plt.xlabel('Route Name')
plt.ylabel('Count')
plt.title('Distribution of Route Names')
plt.xticks(rotation=80)
plt.tight_layout()
plt.show()

# Plot route descriptions
plt.figure(figsize=(18, 6))
route_descs.value_counts().plot(kind='bar')
plt.xlabel('Route Description')
plt.ylabel('Count')
plt.title('Distribution of Route Descriptions')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\moses_y\AppData\Local\Temp\ipykernel_29864\3848751257.py:40: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()

# %%
# Load the trips DataFrame
trips = pd.read_csv(data_folder + 'trips.txt')

# Plot the count of trips by direction id
plt.figure(figsize=(10, 6))
sns.countplot(x='direction_id', data=trips)
plt.xlabel('Direction ID')
plt.ylabel('Count')
plt.title('Count of Trips by Direction ID')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Define the path to the data folder
data_folder = 'C:/Users/moses_y/OneDrive/Desktop/plots/data/'

# Load the GTFS files into DataFrames
agency = pd.read_csv(data_folder + 'agency.txt')
calendar = pd.read_csv(data_folder + 'calendar.txt')
calendar_dates = pd.read_csv(data_folder + 'calendar_dates.txt')
feed_info = pd.read_csv(data_folder + 'feed_info.txt')
frequencies = pd.read_csv(data_folder + 'frequencies.txt')
routes = pd.read_csv(data_folder + 'routes.txt')
shapes = pd.read_csv(data_folder + 'shapes.txt')
stops = pd.read_csv(data_folder + 'stops.txt')
trips = pd.read_csv(data_folder + 'trips.txt')

# Merge 'trips' and 'frequencies' DataFrames on 'trip_id'
trips = trips.merge(frequencies, on='trip_id')

# Convert 'start_time' and 'end_time' columns to datetime type
trips['start_time'] = pd.to_datetime(trips['start_time'], format='%H:%M:%S')
trips['end_time'] = pd.to_datetime(trips['end_time'], format='%H:%M:%S')

# Check if 'trip_duration' column exists in the DataFrame
if 'trip_duration' not in trips.columns:
    # Calculate trip duration
    trips['trip_duration'] = trips['end_time'] - trips['start_time']

# Convert trip_duration to numeric format
trips['trip_duration'] = trips['trip_duration'].dt.total_seconds() / 60

# Filter out invalid or missing data
trips = trips.dropna(subset=['route_id', 'trip_duration'])

# Merge 'trips' DataFrame with 'routes' DataFrame on 'route_id'
trips = trips.merge(routes[['route_id', 'route_long_name']], on='route_id')

# Assign route names to route IDs for readability
trips.rename(columns={'route_long_name': 'route_name'}, inplace=True)

# Check if any valid trip durations exist
if trips['trip_duration'].empty:
    print("No valid trip durations found.")
else:
    # Calculate average trip duration by route name
    average_trip_duration_by_name = trips.groupby('route_name')['trip_duration'].mean()
    average_trip_duration = average_trip_duration_by_name.mean()
    print("Average Trip Duration:", average_trip_duration)

    # Plot the bar chart for average trip duration by route name
    plt.figure(figsize=(16, 8))  # Adjust the figure size
    ax = sns.barplot(x=average_trip_duration_by_name.index, y=average_trip_duration_by_name.values)
    plt.xlabel('Route Name')
    plt.ylabel('Average Trip Duration (minutes)')
    plt.title(f'Average Trip Duration by Route Name\n(Average: {average_trip_duration:.2f} minutes)')  # Include average in the plot title
    plt.xticks(rotation=80)  # Rotate the x-axis labels by 30 degrees
    plt.tight_layout()  # Adjust the spacing of the plot

    # Adjust the x-axis labels to start at 0
    ax.set_xlim(left=10)
    plt.ylim(0, None)

    plt.show()
# Out:
# Average Trip Duration: 299.63325617283954

# %%
print(trips.columns)
# Out:
# Index(['route_id', 'service_id', 'trip_id', 'trip_headsign', 'direction_id',
#        'block_id', 'shape_id', 'start_time', 'end_time', 'headway_secs',
#        'trip_duration'],
#       dtype='object')

# %%
print(frequencies.columns)
# Out:
# Index(['trip_id', 'start_time', 'end_time', 'headway_secs'], dtype='object')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Define the path to the data folder
data_folder = 'C:/Users/moses_y/OneDrive/Desktop/plots/data/'

# Load the GTFS files into DataFrames
agency = pd.read_csv(data_folder + 'agency.txt')
calendar = pd.read_csv(data_folder + 'calendar.txt')
calendar_dates = pd.read_csv(data_folder + 'calendar_dates.txt')
feed_info = pd.read_csv(data_folder + 'feed_info.txt')
frequencies = pd.read_csv(data_folder + 'frequencies.txt')
routes = pd.read_csv(data_folder + 'routes.txt')
shapes = pd.read_csv(data_folder + 'shapes.txt')
stops = pd.read_csv(data_folder + 'stops.txt')
trips = pd.read_csv(data_folder + 'trips.txt')

# Merge 'trips' and 'frequencies' DataFrames on 'trip_id'
trips = trips.merge(frequencies, on='trip_id')

# Convert 'start_time' and 'end_time' columns to datetime type
trips['start_time'] = pd.to_datetime(trips['start_time'], format='%H:%M:%S')
trips['end_time'] = pd.to_datetime(trips['end_time'], format='%H:%M:%S')

# Check if 'trip_duration' column exists in the DataFrame
if 'trip_duration' not in trips.columns:
    # Calculate trip duration
    trips['trip_duration'] = trips['end_time'] - trips['start_time']

# Convert trip_duration to numeric format
trips['trip_duration'] = trips['trip_duration'].dt.total_seconds() / 60

# Filter out invalid or missing data
trips = trips.dropna(subset=['route_id', 'trip_duration'])

# Check if any valid trip durations exist
if trips['trip_duration'].empty:
    print("No valid trip durations found.")
else:
    # Calculate average trip duration
    average_trip_duration = trips['trip_duration'].mean()
    print("Average Trip Duration:", average_trip_duration)

    # Extract the 'route_long_name' column from 'routes' DataFrame
    route_names = routes['route_long_name']

    # Plot the bar chart for average trip duration by route name
    plt.figure(figsize=(16, 8))
    ax = sns.barplot(x=route_names, y='trip_duration', data=trips)
    plt.xlabel('Route Name')
    plt.ylabel('Trip Duration (minutes)')
    plt.title(f'Average Trip Duration by Route Name\n(Average: {average_trip_duration:.2f} minutes)')
    plt.xticks(rotation=90)
    plt.tight_layout()
    plt.ylim(0, None)
    plt.show()
# Out:
# Average Trip Duration: 299.63315266486

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Define the path to the data folder
data_folder = 'C:/Users/moses_y/OneDrive/Desktop/plots/data/'

# Load the GTFS files into DataFrames
agency = pd.read_csv(data_folder + 'agency.txt')
calendar = pd.read_csv(data_folder + 'calendar.txt')
calendar_dates = pd.read_csv(data_folder + 'calendar_dates.txt')
feed_info = pd.read_csv(data_folder + 'feed_info.txt')
frequencies = pd.read_csv(data_folder + 'frequencies.txt')
routes = pd.read_csv(data_folder + 'routes.txt')
shapes = pd.read_csv(data_folder + 'shapes.txt')
stops = pd.read_csv(data_folder + 'stops.txt')
trips = pd.read_csv(data_folder + 'trips.txt')

# Merge 'trips' and 'frequencies' DataFrames on 'trip_id'
trips = trips.merge(frequencies, on='trip_id')

# Convert 'start_time' and 'end_time' columns to datetime type
trips['start_time'] = pd.to_datetime(trips['start_time'], format='%H:%M:%S')
trips['end_time'] = pd.to_datetime(trips['end_time'], format='%H:%M:%S')

# Check if 'trip_duration' column exists in the DataFrame
if 'trip_duration' not in trips.columns:
    # Calculate trip duration
    trips['trip_duration'] = trips['end_time'] - trips['start_time']

# Convert trip_duration to numeric format
trips['trip_duration'] = trips['trip_duration'].dt.total_seconds() / 60

# Filter out invalid or missing data
trips = trips.dropna(subset=['route_id', 'trip_duration'])

# Check if any valid trip durations exist
if trips['trip_duration'].empty:
    print("No valid trip durations found.")
else:
    # Calculate average trip duration
    average_trip_duration = trips['trip_duration'].mean()
    print("Average Trip Duration:", average_trip_duration)

    # Extract the 'route_long_name' column from 'routes' DataFrame
    route_names = routes['route_long_name']

    # Sort route names alphabetically
    route_names_sorted = route_names.sort_values()

    # Plot the bar chart for average trip duration by route name
    plt.figure(figsize=(16, 8))
    ax = sns.barplot(x=route_names_sorted, y='trip_duration', data=trips)
    plt.xlabel('Route Name')
    plt.ylabel('Trip Duration (minutes)')
    plt.title(f'Average Trip Duration by Route Name\n(Average: {average_trip_duration:.2f} minutes)')
    plt.xticks(rotation=90)
    plt.tight_layout()
    plt.ylim(0, None)
    plt.show()
# Out:
# Average Trip Duration: 299.63315266486

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Define the path to the data folder
data_folder = 'C:/Users/moses_y/OneDrive/Desktop/plots/data/'

# Load the GTFS files into DataFrames
agency = pd.read_csv(data_folder + 'agency.txt')
calendar = pd.read_csv(data_folder + 'calendar.txt')
calendar_dates = pd.read_csv(data_folder + 'calendar_dates.txt')
feed_info = pd.read_csv(data_folder + 'feed_info.txt')
frequencies = pd.read_csv(data_folder + 'frequencies.txt')
routes = pd.read_csv(data_folder + 'routes.txt')
shapes = pd.read_csv(data_folder + 'shapes.txt')
stops = pd.read_csv(data_folder + 'stops.txt')
trips = pd.read_csv(data_folder + 'trips.txt')

# Merge 'trips', 'frequencies', and 'routes' DataFrames
merged_data = trips.merge(frequencies, on='trip_id')
merged_data = merged_data.merge(routes, on='route_id')

# Convert 'start_time' and 'end_time' columns to datetime type
merged_data['start_time'] = pd.to_datetime(merged_data['start_time'], format='%H:%M:%S')
merged_data['end_time'] = pd.to_datetime(merged_data['end_time'], format='%H:%M:%S')

# Check if 'trip_duration' column exists in the DataFrame
if 'trip_duration' not in merged_data.columns:
    # Calculate trip duration
    merged_data['trip_duration'] = merged_data['end_time'] - merged_data['start_time']

# Convert trip_duration to numeric format
merged_data['trip_duration'] = merged_data['trip_duration'].dt.total_seconds() / 60

# Filter out invalid or missing data
merged_data = merged_data.dropna(subset=['route_id', 'trip_duration'])

# Check if any valid trip durations exist
if merged_data['trip_duration'].empty:
    print("No valid trip durations found.")
else:
    # Calculate average trip duration
    average_trip_duration = merged_data['trip_duration'].mean()
    print("Average Trip Duration:", average_trip_duration)

    # Extract the 'route_long_name' column from the merged DataFrame
    route_names = merged_data['route_long_name']

    # Sort route names alphabetically
    route_names_sorted = route_names.sort_values()

    # Plot the bar chart for average trip duration by route name
    plt.figure(figsize=(18, 9))
    ax = sns.barplot(x=route_names_sorted, y='trip_duration', data=merged_data)
    plt.xlabel('Route Name')
    plt.ylabel('Trip Duration (minutes)')
    plt.title(f'Average Trip Duration by Route Name\n(Average: {average_trip_duration:.2f} minutes)')
    plt.xticks(rotation=90)
    plt.tight_layout()
    plt.ylim(0, None)
    plt.show()
# Out:
# Average Trip Duration: 299.63315266486

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Define the path to the data folder
data_folder = 'C:/Users/moses_y/OneDrive/Desktop/plots/data/'

# Load the GTFS files into DataFrames
agency = pd.read_csv(data_folder + 'agency.txt')
calendar = pd.read_csv(data_folder + 'calendar.txt')
calendar_dates = pd.read_csv(data_folder + 'calendar_dates.txt')
feed_info = pd.read_csv(data_folder + 'feed_info.txt')
frequencies = pd.read_csv(data_folder + 'frequencies.txt')
routes = pd.read_csv(data_folder + 'routes.txt')
shapes = pd.read_csv(data_folder + 'shapes.txt')
stops = pd.read_csv(data_folder + 'stops.txt')
trips = pd.read_csv(data_folder + 'trips.txt')

# Merge 'trips', 'frequencies', and 'routes' DataFrames
merged_data = trips.merge(frequencies, on='trip_id')
merged_data = merged_data.merge(routes, on='route_id')

# Convert 'start_time' and 'end_time' columns to datetime type
merged_data['start_time'] = pd.to_datetime(merged_data['start_time'], format='%H:%M:%S')
merged_data['end_time'] = pd.to_datetime(merged_data['end_time'], format='%H:%M:%S')

# Check if 'trip_duration' column exists in the DataFrame
if 'trip_duration' not in merged_data.columns:
    # Calculate trip duration
    merged_data['trip_duration'] = merged_data['end_time'] - merged_data['start_time']

# Convert trip_duration to numeric format
merged_data['trip_duration'] = merged_data['trip_duration'].dt.total_seconds() / 60

# Filter out invalid or missing data
merged_data = merged_data.dropna(subset=['route_id', 'trip_duration'])

# Check if any valid trip durations exist
if merged_data['trip_duration'].empty:
    print("No valid trip durations found.")
else:
    # Calculate average trip duration
    average_trip_duration = merged_data['trip_duration'].mean()
    print("Average Trip Duration:", average_trip_duration)

    # Extract the 'route_long_name' column from the trips DataFrame
    route_names = trips.merge(routes, on='route_id')['route_long_name']

    # Sort route names alphabetically
    route_names_sorted = route_names.sort_values()

    # Plot the bar chart for average trip duration by route name
    plt.figure(figsize=(18, 9))
    ax = sns.barplot(x=route_names_sorted, y='trip_duration', data=merged_data)
    plt.xlabel('Route Name')
    plt.ylabel('Trip Duration (minutes)')
    plt.title(f'Average Trip Duration by Route Name\n(Average: {average_trip_duration:.2f} minutes)')
    plt.xticks(rotation=90)
    plt.tight_layout()
    plt.ylim(0, None)
    plt.show()
# Out:
# Average Trip Duration: 299.63315266486
